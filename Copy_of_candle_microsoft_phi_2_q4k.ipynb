# %%
# Either build Candle Phi example from source:
# !apt install cargo
# !git clone https://github.com/huggingface/candle
# %cd candle
# !cargo build --example phi --release --features cuda
# !ln -s /content/candle/target/release/examples/phi ../phi
# %cd ..
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cargo is already the newest version (1.70.0+dfsg0ubuntu1~bpo2-0ubuntu0.22.04.2).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# fatal: destination path 'candle' already exists and is not an empty directory.
# /content/candle
#     Updating crates.io index
# ...
#   Downloaded is-terminal v0.4.10
#   Downloaded futures v0.3.30
#   Downloaded anstyle v1.0.4
#   Downloaded zerofrom v0.1.3
#   Downloaded want v0.3.1
#   Downloaded utf8parse v0.2.1
#   Downloaded walkdir v2.4.0
#   Downloaded unicode-width v0.1.11
#   Downloaded zstd-safe v6.0.6
#   Downloaded yoke v0.7.3
#   Downloaded monostate v0.1.11
#   Downloaded indexmap v2.1.0
#   Downloaded cast v0.3.0
#   Downloaded indexmap v1.9.3
#   Downloaded lz4 v1.24.0
#   Downloaded yew-agent v0.2.0
#   Downloaded gloo-dialogs v0.1.1
#   Downloaded indicatif v0.17.7
#   Downloaded indoc v2.0.4
# ...

# %%
# Or download a prebuilt binary:
# !wget https://github.com/niutech/candle/releases/download/0.3.1/phi
# !chmod a+x phi
# Out:
# --2024-01-07 18:16:01--  https://github.com/niutech/candle/releases/download/0.3.1/phi
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-01-07 18:16:01 ERROR 404: Not Found.

# %%
prompt = "write an algorithm to sort an array with python" # @param {type: "string"}
max_length = 1024 # @param {type: "integer"}
quantized = False # @param {type: "boolean"}
quantized_param = "--quantized" if quantized else ""
# !./phi $quantized_param --model 2 -n $max_length --prompt "$prompt"
# Out:
# avx: true, neon: false, simd128: false, f16c: true
# temp: 0.00 repeat-penalty: 1.10 repeat-last-n: 64
# retrieved the files in 10.368717ms
# loaded the model in 6.073004528s
# starting the inference loop
# write an algorithm to sort an array with python
# #include <stdio.h>
# int main() {
#   int arr[] = {5, 2, 9, 1, 7};
#   int n = sizeof(arr) / sizeof(arr[0]);
#
#   for (int i = 0; i < n - 1; i++) {
#     for (int j = 0; j < n - i - 1; j++) {
#       if (arr[j] > arr[j + 1]) {
#         int temp = arr[j];
#         arr[j] = arr[j + 1];
#         arr[j + 1] = temp;
#       }
#     }
#   }
#
#   for (int i = 0; i < n; i++) {
#     printf("%d ", arr[i]);
#   }
#
#   return 0;
# }
#
# 214 tokens generated (16.68 token/s)
